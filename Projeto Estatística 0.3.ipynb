# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Gastos De Deputados
# Iremos analisar os gastos dos deputados e partidos brasileiros entre os anos de 2009 e 2019 a partir de dados disponibilizados pelo Governo Federal.
#
# ### Escopo Do Projeto
# •Neste projeto iremos fazer uma analise feral dos gastos, ou seja, gastos dos partidos, gastos por ano entre outros.
#
# •Assim poderemos ter uma noção de quanto é gasto anualmente por deputados e seus partidos.

# %% [markdown]
# ### Leitura de todos os CSV'S.

# %%
g2009 = pd.read_csv('projeto/Ano-2009.csv',sep = ';')
g2010 = pd.read_csv('projeto/Ano-2010.csv',sep = ';')
g2011 = pd.read_csv('projeto/Ano-2011.csv',sep = ';')
g2012 = pd.read_csv('projeto/Ano-2012.csv',sep = ';')
g2013 = pd.read_csv('projeto/Ano-2013.csv',sep = ';')
g2014 = pd.read_csv('projeto/Ano-2014.csv',sep = ';')
g2015 = pd.read_csv('projeto/Ano-2015.csv',sep = ';')
g2016 = pd.read_csv('projeto/Ano-2016.csv',sep = ';')
g2017 = pd.read_csv('projeto/Ano-2017.csv',sep = ';')
g2018 = pd.read_csv('projeto/Ano-2018.csv',sep = ';')
g2019 = pd.read_csv('projeto/Ano-2019.csv',sep = ';')

# %% [markdown]
# ### Concatenando e filtrando somente os dados necessários.

# %%
gAll = pd.concat([g2009,g2010,g2011,g2012,g2013,g2014,g2015,g2016,g2017,g2018,g2019], sort = False)

# %%
filt = gAll.iloc[0:,[0,5,6,9,12,19,20,21]]

# %%
filt
# Out:
#          txNomeParlamentar sgUF  sgPartido  \
# 0            ATHOS AVELINO  NaN        NaN
# 1          FERNANDO ESTIMA  NaN        NaN
# 2              JOÃO FONTES  NaN        NaN
# 3             LUIZ MOREIRA  NaN        NaN
# 4             LUIZ MOREIRA  NaN        NaN
# 5       PROFESSOR LUIZINHO  NaN        NaN
# 6       PROFESSOR LUIZINHO  NaN        NaN
# 7             JAIRO ATAÍDE   MG        DEM
# 8             JAIRO ATAÍDE   MG        DEM
# 9             JAIRO ATAÍDE   MG        DEM
# 10            JAIRO ATAÍDE   MG        DEM
# 11            JAIRO ATAÍDE   MG        DEM
# 12            JAIRO ATAÍDE   MG        DEM
# 13            JAIRO ATAÍDE   MG        DEM
# 14            JAIRO ATAÍDE   MG        DEM
# 15            JAIRO ATAÍDE   MG        DEM
# 16            JAIRO ATAÍDE   MG        DEM
# 17            JAIRO ATAÍDE   MG        DEM
# 18            JAIRO ATAÍDE   MG        DEM
# 19            JAIRO ATAÍDE   MG        DEM
# 20            JAIRO ATAÍDE   MG        DEM
# 21            JAIRO ATAÍDE   MG        DEM
# 22            JAIRO ATAÍDE   MG        DEM
# 23            JAIRO ATAÍDE   MG        DEM
# 24            JAIRO ATAÍDE   MG        DEM
# 25            JAIRO ATAÍDE   MG        DEM
# 26            JAIRO ATAÍDE   MG        DEM
# 27            JAIRO ATAÍDE   MG        DEM
# 28            JAIRO ATAÍDE   MG        DEM
# 227295                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227296                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227297                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227298                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227299                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227300                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227301                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227302                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227303                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227304                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227305                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227306                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227307                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227308                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227309                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227310                      COMBUSTÍVEIS E LUBRIFICANTES.
# 227311                                          TELEFONIA
# 227312                                   SERVIÇOS POSTAIS
# 227313      LOCAÇÃO OU FRETAMENTO DE VEÍCULOS AUTOMOTORES
# 227314                              Emissão Bilhete Aéreo
# 227315                              Emissão Bilhete Aéreo
# 227316                              Emissão Bilhete Aéreo
# 227317                              Emissão Bilhete Aéreo
#
#                                   txtFornecedor  vlrLiquido  numMes  numAno
# 0                               Cia Aérea - GOL     -334.42       7    2009
# 1                               Cia Aérea - GOL      539.04       7    2009
# 2                               Cia Aérea - GOL     -149.62      10    2009
# 3                               Cia Aérea - GOL      398.62       8    2009
# 4                               Cia Aérea - GOL      678.62       8    2009
# 5                               Cia Aérea - GOL     1105.74      10    2009
# 6                               Cia Aérea - GOL       -4.50      10    2009
# 7                                         CEMIG       98.18       4    2009
# 8                                         CEMIG       63.07       6    2009
# 9                                         CEMIG       73.21       9    2009
# 10                                        CEMIG       74.77       3    2009
# 11                                        CEMIG       74.18       5    2009
# 12                                        CEMIG       69.26      11    2009
# 13                                        CEMIG       74.64      10    2009
# 14                                        CEMIG       77.56      12    2009
# 15                                        CEMIG       82.65       8    2009
# 16                                        CEMIG       69.64       7    2009
# 17                                       COPASA       19.12       3    2009
# 18                                       COPASA      198.35       4    2009
# 19                                       COPASA      114.29       5    2009
# 20                                       COPASA       20.75       6    2009
# 21                                       COPASA      228.39       7    2009
# 22                                       COPASA       40.22       8    2009
# 23                                       COPASA       50.95      10    2009
# 24                                       COPASA       20.75      11    2009
# 25                                       COPASA       20.75      12    2009
# 26                                           OI      314.81       2    2009
# 27                      TELEMAR NORTE LESTE S/A       36.99       3    2009
# 28                         BPA TRANSPORTES LTDA       33.55       5    2009
# 29                           COOBRAS RÁDIO TAXI       10.00       6    2009
# ...                                         ...         ...     ...     ...
# 227288       Liberio joao de santana & cia ltda      237.15       9    2019
# 227289                        MOURAO & CIA LTDA      225.44      10    2019
# 227290                  POSTO ALTO DA RAJA LTDA      157.62      11    2019
# 227291                        POSTO BR 494 LTDA      231.92      10    2019
# 227292  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      200.74       9    2019
# 227293  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      239.88       9    2019
# 227294  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      219.77       9    2019
# 227295  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      249.83       9    2019
# 227296  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      200.88       9    2019
# 227297  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      163.83      10    2019
# 227298  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      256.81      10    2019
# 227299  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      201.08      10    2019
# 227300  POSTO DE COMBUSTIVEL VILA CRUZEIRO LTDA      184.99      11    2019
# 227301                      Posto Mario Werneck      214.75       9    2019
# 227302                             Posto Matuca      256.95      10    2019
# 227303                         POSTO MG 10 LTDA      224.34      10    2019
# 227304                    POSTO PONTO ALTO LTDA      240.53      10    2019
# 227305          SOCIEDADE COMERCIAL CANAA -LTDA      207.04      10    2019
# 227306          SOCIEDADE COMERCIAL CANAA -LTDA      180.01      10    2019
# 227307          SOCIEDADE COMERCIAL CANAA -LTDA      168.28      10    2019
# 227308          SOCIEDADE COMERCIAL CANAA -LTDA      164.64      10    2019
# 227309          SOCIEDADE COMERCIAL CANAA -LTDA      214.04      11    2019
# 227310                 SULAMITA NAVES DE AGUIAR      228.90       9    2019
# 227311                                    RAMAL       16.93       8    2019
# 227312            CORREIOS - SEDEX CONVENCIONAL       88.16      11    2019
# 227313                      M&M RENT A CAR LTDA     3935.20      10    2019
# 227314                         Cia Aérea - AZUL      401.57       8    2019
# 227315                         Cia Aérea - AZUL     1010.57      10    2019
# 227316                         Cia Aérea - AZUL      759.57       9    2019
# 227317                          Cia Aérea - TAM      377.59       8    2019
#
# [3779587 rows x 8 columns]

# %% [markdown]
# ### Removendo os dados faltosos da coluna dos "Partidos".

# %%
filt.update(filt['sgPartido'].fillna('test'))

# %% [markdown]
# ### Coletando todos os partidos dos e adicionando a uma lista.

# %%
filt['sgPartido'] = filt['sgPartido']*-1

# %%
soma = 0
for x in filt['vlrLiquido']:
    check = True
    if x < 0:
        soma = soma + 1
soma
# Out:
# 148891

# %% [markdown]
# #### Separando por partidos.

# %%
a = filt.groupby([filt['sgPartido']])
a.first()
# Out:
#                       txNomeParlamentar sgUF  \
# sgPartido
# AVANTE                        LUIS TIBÉ   MG
# CIDADANIA                  RUBENS BUENO   PR
# DEM                        JAIRO ATAÍDE   MG
# MDB                        MARIA HELENA   RR
# NOVO                  MARCEL VAN HATTEM   RS
# PATRI                 ERIVELTON SANTANA   BA
# PATRIOTA                  PASTOR EURICO   PE
# PCdoB                       ALDO REBELO   SP
# PDT                    POMPEO DE MATTOS   RS
# PEN                         NILMAR RUIZ   TO
# PHS                      ULDURICO PINTO   BA
# PL                   PAULO FREIRE COSTA   SP
# PMDB                     NELSON BORNIER   RJ
# PMN                         FÁBIO FARIA   RN
# PODE                      MARCELO ORTIZ   SP
# PP                          ODELMO LEÃO   MG
# PP**                       SIMÃO SESSIM   RJ
# PPL                     ULDURICO JUNIOR   BA
# PPS                     FERNANDO CORUJA   SC
# PR                        AIRTON ROVEDA   PR
# PRB                       EDUARDO LOPES   RJ
# PROS                  SALVADOR ZIMBALDI   SP
# PRP                  CHICO DAS VERDURAS   RR
# PRTB                            JUVENIL   MG
# PSB                        MARIA HELENA   RR
# PSC                   RÉGIS DE OLIVEIRA   SP
# PSD                        VILMAR ROCHA   GO
# PSDB           ANTONIO CARLOS PANNUNZIO   SP
# PSDC                  DUDU LUIZ EDUARDO   RJ
# PSL                       CARLOS MANATO   ES
# PSOL                       IVAN VALENTE   SP
# PT                      JOSEPH BANDEIRA   BA
# PTB                        SILVIO COSTA   PE
# PTC                      ANTONIO FEIJÃO   AP
# PTdoB                 VINICIUS CARVALHO   SP
# PV                      HENRIQUE AFONSO   AC
# REDE                      MIRO TEIXEIRA   RJ
# REPUBLICANOS           CELSO RUSSOMANNO   SP
# S.PART.                   NATAN DONADON   RO
# SD                    HENRIQUE OLIVEIRA   AM
# SOLIDARIEDADE          AUGUSTO COUTINHO   PE
# test                      ATHOS AVELINO  NaN
#
#                                                     txtDescricao  \
# sgPartido
# AVANTE                                                 TELEFONIA
# CIDADANIA                                       PASSAGENS AÉREAS
# DEM            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# MDB                                                    TELEFONIA
# NOVO           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PATRI                                           PASSAGENS AÉREAS
# PATRIOTA                                        PASSAGENS AÉREAS
# PCdoB          MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PDT            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PEN            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PHS            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PL                                              PASSAGENS AÉREAS
# PMDB           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PMN            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PODE                                                   TELEFONIA
# PP                                         Emissão Bilhete Aéreo
# PP**           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PPL            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PPS            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PR             MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PRB            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PROS           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PRP            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PRTB                                                   TELEFONIA
# PSB            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PSC            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PSD                                                    TELEFONIA
# PSDB           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PSDC           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PSL            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PSOL           MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PT             MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PTB            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PTC            MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PTdoB          MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# PV             MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# REDE                                                   TELEFONIA
# REPUBLICANOS                                           TELEFONIA
# S.PART.        MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# SD             MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# SOLIDARIEDADE                                   PASSAGENS AÉREAS
# test                                       Emissão Bilhete Aéreo
#
#                                                    txtFornecedor  vlrLiquido  \
# sgPartido
# AVANTE                                               TNL PCS S.A      306.03
# CIDADANIA                         GOL LINHAS AÉREAS INTELIGENTES      368.62
# DEM                                                        CEMIG       98.18
# MDB                                            CELULAR FUNCIONAL      135.74
# NOVO                              BELLER COMERCIO DE PAPEIS LTDA       37.71
# PATRI                                       TAM LINHAS AREAS S/A      372.72
# PATRIOTA                                 TAM - LINHAS AÉREAS S/A      846.00
# PCdoB                                 ADIRSON QUIRINO DOS SANTOS     1446.09
# PDT                                                     EMBRATEL       20.15
# REPUBLICANOS        2    2011
# S.PART.             5    2011
# SD                  4    2011
# SOLIDARIEDADE       1    2011
# test                7    2009

# %% [markdown]
# #### Total Gasto em todos os Anos.

# %%
filt['vlrLiquido'].sum()
# Out:
# 2036183909.0199993

# %% [markdown]
# #### Total Gasto em todos os anos separadamente.

# %%
total2009 = g2009['vlrLiquido'].sum()
total2010 = g2010['vlrLiquido'].sum()
total2011 = g2011['vlrLiquido'].sum()
total2012 = g2012['vlrLiquido'].sum()
total2013 = g2013['vlrLiquido'].sum()
total2014 = g2014['vlrLiquido'].sum()
total2015 = g2015['vlrLiquido'].sum()
total2016 = g2016['vlrLiquido'].sum()
total2017 = g2017['vlrLiquido'].sum()
total2018 = g2018['vlrLiquido'].sum()
total2019 = g2019['vlrLiquido'].sum()


df = pd.DataFrame({'Gastos': [total2009, total2010, total2011, total2012,total2013,total2014,total2015,total2016,total2017,total2018,total2019]},
 index=['2009','2010', '2011','2012','2013','2014','2015','2016','2017','2018','2019'])

# %%
plt.title('Gastos dos Deputados,2009-2019')
plt.xlabel('Ano')
plt.ylabel('R$ em Bilhões')
df['Gastos'].plot.bar()

# %% [markdown]
# ###### Podemos notar que de 2009 ate 2017 os gastos aumentarão significadamente e em 2018 houve um pouco menos de gastos.
# Obs: Os gastos de 2019 estão incompletos.

# %% [markdown]
# ### Gastos mensais.

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2009')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2009 = g2009.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2009.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2010')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2010 = g2010.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2010.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2011')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2011 = g2011.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2011.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2012')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2012 = g2012.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2012.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2013')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2013 = g2013.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2013.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2014')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2014 = g2014.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2014.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2015')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2015 = g2015.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2015.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2016')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2016 = g2016.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2016.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2017')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2017 = g2017.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2017.plot()

# %%
plt.title('Gastos dos Deputados,Jan-Dez/2018')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2018 = g2018.groupby(['numMes']).sum()['vlrLiquido']
soma_mes2018.plot()

# %%
soma_mes2019 = g2019.groupby(['numMes']).sum()['vlrLiquido']
plt.title('Gastos dos Deputados,Jan-Dez/2019')
plt.xlabel('Mês')
plt.ylabel('R$ em Bilhões')
soma_mes2019.plot()

# %% [markdown]
# #### •Podemos notar que geralmente no fim do ano(Outubro - Dezembro), os gastos chegam ao seus valores máximos, e que no meio do ano(Abril - Agosto) os gastos tem uma redução em relação aos outros meses.

# %% [markdown]
# ### Dados sobre com o que mais foi gasto em cada ano.

# %%
Qntd2009 = g2009['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2009')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2009.T.plot.bar()

# %%
Qntd2010 = g2010['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2010')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2010.T.plot.bar()

# %%
Qntd2011 = g2011['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2011')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2011.T.plot.bar()

# %%
Qntd2012 = g2012['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2012')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2012.T.plot.bar()

# %%
Qntd2013 = g2013['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2013')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2013.T.plot.bar()

# %%
Qntd2014 = g2014['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2014')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2014.T.plot.bar()

# %%
Qntd2015 = g2015['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2015')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2015.T.plot.bar()

# %%
Qntd2016 = g2016['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2016')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2016.T.plot.bar()

# %%
Qntd2017 = g2017['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2017')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2017.T.plot.bar()

# %%
Qntd2018 = g2018['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2018')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2018.T.plot.bar()

# %%
Qntd2019 = g2019['txtDescricao'].value_counts()
plt.title('Quandidade de Serviços / 2019')
plt.xlabel('Serviços')
plt.ylabel('Quantidade')
Qntd2019.T.plot.bar()

# %%
QntdALL = pd.DataFrame([Qntd2009,Qntd2010,Qntd2011,Qntd2012,Qntd2013,Qntd2014,Qntd2015,Qntd2016,Qntd2017,Qntd2018,Qntd2019,],index = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019',])

# %%
QntdALL.T.plot.bar()

# %%
QntdALL1 = filt['txtDescricao'].value_counts()

# %%
QntdALL1.T.plot.bar()

# %% [markdown]
# #### Na maioria dos anos o que mais se provoca gastos são emissões de bilhetes aéreos.

# %% [markdown]
# ### Partidos que mais Gastaram

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2009 = g2009.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2010 = g2010.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2011 = g2011.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2012 = g2012.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2013 = g2013.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2014 = g2014.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2015 = g2015.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2016 = g2016.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2017 = g2017.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2018 = g2018.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
plt.ylabel('R$ em Milhões')
gastos_partidos2019 = g2019.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
test = pd.DataFrame([gastos_partidos2009,gastos_partidos2010,gastos_partidos2011,gastos_partidos2012,gastos_partidos2013,gastos_partidos2014,gastos_partidos2015,gastos_partidos2016,gastos_partidos2017,gastos_partidos2018,gastos_partidos2019,],index = ['2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019',])

# %%
test.T.plot.bar()

# %%
plt.ylabel('R$ em 100 Milhões')
gastoTotal = filt.groupby(['sgPartido']).sum()['vlrLiquido'].T.plot.bar()

# %%
filt.groupby(['sgPartido']).sum()['vlrLiquido']['PT']
# Out:
# 283883727.0399528
